# %%
num = int(input("Enter the number"))
if num <=1:
    print("Not an prime")
else:
    for i in range(1 , num+1):
        if num % i ==0:
            print(f" It's {num} an prime number ")
        break
    else:
       print("The number is not an prime number")
# Out:
#  It's 4 an prime number
